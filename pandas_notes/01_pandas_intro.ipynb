# %% [markdown]
# Pandas is a Python library used for data manipulation and analysis. It allows you to have heterogeneous data (objects of different types).
#
# It's a programmable way that you can run spreadsheets.

# %%
import pandas

pandas.__version__
# Out:
# '0.19.2'

# %%
# Reading a csv file
pandas.read_csv('./scipy-2017-tutorial-pandas-master/data/gapminder.tsv', delimiter='\t') # dumps out the data set
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
df = pandas.read_csv('./scipy-2017-tutorial-pandas-master/data/gapminder.tsv', delimiter='\t')

# %%
df.head() # gives you the first five rows
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
import pandas as pd # importing pandas as an alias

# %%
df = pd.read_csv('./scipy-2017-tutorial-pandas-master/data/gapminder.tsv', delimiter='\t')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape # An attribute with number of rows and columns
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 66.6+ KB

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
country_df = df['country'] # Single column

# %%
df[['country', 'continent', 'year']].head() # Multiple columns
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.columns # Attribute for list of columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
del df['country'] # Python way of deleting a column

# %%
df.drop('continent', axis=1) # A pandas method to delete a column, axis=1 for columns
# Out:
#       year  lifeExp       pop    gdpPercap
# 0     1952   28.801   8425333   779.445314
# 1     1957   30.332   9240934   820.853030
# 2     1962   31.997  10267083   853.100710
# 3     1967   34.020  11537966   836.197138
# 4     1972   36.088  13079460   739.981106
# 5     1977   38.438  14880372   786.113360
# 6     1982   39.854  12881816   978.011439
# 7     1987   40.822  13867957   852.395945
# 8     1992   41.674  16317921   649.341395
# 9     1997   41.763  22227415   635.341351
# 10    2002   42.129  25268405   726.734055
# 11    2007   43.828  31889923   974.580338
# 12    1952   55.230   1282697  1601.056136
# 13    1957   59.280   1476505  1942.284244
# 14    1962   64.820   1728137  2312.888958
# 15    1967   66.220   1984060  2760.196931
# 16    1972   67.690   2263554  3313.422188
# 17    1977   68.930   2509048  3533.003910
# 18    1982   70.420   2780097  3630.880722
# 19    1987   72.000   3075321  3738.932735
# 20    1992   71.581   3326498  2497.437901
# ...

# %%
df.head()
# Out:
#   continent  year  lifeExp       pop   gdpPercap
# 0      Asia  1952   28.801   8425333  779.445314
# 1      Asia  1957   30.332   9240934  820.853030
# 2      Asia  1962   31.997  10267083  853.100710
# 3      Asia  1967   34.020  11537966  836.197138
# 4      Asia  1972   36.088  13079460  739.981106

# %%
df = pd.read_csv('./scipy-2017-tutorial-pandas-master/data/gapminder.tsv', delimiter='\t')

# %%
# There are three ways you can subset rows

df.loc[0] # loc attribute allows you to pull out different rows of data
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.loc[99]
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap       721.186
# Name: 99, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Sri\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1410                 if key not in ax:
# -> 1411                     error()
#    1412             except TypeError as e:
#
# D:\Sri\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#
# KeyError: 'the label [-1] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-c88d0e464df6> in <module>()
# ----> 1 df.loc[-1]
#
# D:\Sri\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
df.iloc[0] # Index location
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.iloc[99]
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap       721.186
# Name: 99, dtype: object

# %%
df.iloc[-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.ix[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.ix[[0, 99, 999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.ix[[0, 99, 999], ['country', 'lifeExp', 'gdpPercap']]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
df.loc[[0, 99, 999], ['country', 'lifeExp', 'gdpPercap']]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
df.iloc[[0, 99, 999], [0, 3, 5]]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
le_mean = df['lifeExp'].mean()

# %%
le_mean
# Out:
# 59.47443936619713

# %%
df.loc[df['lifeExp'] > le_mean, :]
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 14               Albania    Europe  1962   64.820   1728137   2312.888958
# 15               Albania    Europe  1967   66.220   1984060   2760.196931
# 16               Albania    Europe  1972   67.690   2263554   3313.422188
# 17               Albania    Europe  1977   68.930   2509048   3533.003910
# 18               Albania    Europe  1982   70.420   2780097   3630.880722
# 19               Albania    Europe  1987   72.000   3075321   3738.932735
# 20               Albania    Europe  1992   71.581   3326498   2497.437901
# 21               Albania    Europe  1997   72.950   3428038   3193.054604
# 22               Albania    Europe  2002   75.651   3508512   4604.211737
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 30               Algeria    Africa  1982   61.368  20033753   5745.160213
# 31               Algeria    Africa  1987   65.799  23254956   5681.358539
# ...

# %%
df.groupby('year')

# %%
df.groupby('year')['lifeExp'].mean() # Mean of lifeExp year-wise
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')[['lifeExp', 'gdpPercap']].mean()
# Out:
#         lifeExp     gdpPercap
# year
# 1952  49.057620   3725.276046
# 1957  51.507401   4299.408345
# 1962  53.609249   4725.812342
# 1967  55.678290   5483.653047
# 1972  57.647386   6770.082815
# 1977  59.570157   7313.166421
# 1982  61.533197   7518.901673
# 1987  63.212613   7900.920218
# 1992  64.160338   8158.608521
# 1997  65.014676   9090.175363
# 2002  65.694923   9917.848365
# 2007  67.007423  11680.071820

# %%
(df.
 groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].
 mean()
).reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %%
df.groupby('continent')['country'].nunique() # Number of countries in each continent
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
gyle = df.groupby('year')['lifeExp'].mean() # Group mean of lifeExp by year

# %%
gyle
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
gyle.plot()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

gyle.plot()

# %%
gyle
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
type(gyle)
# Out:
# pandas.core.series.Series

# %%
df = gyle.reset_index()

# %%
df.to_csv('./scipy-2017-tutorial-pandas-master/output/lifeExp_by_year.csv', index=False)
